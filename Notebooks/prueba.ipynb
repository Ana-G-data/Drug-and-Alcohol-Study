# %%
import pandas as pd

# %%
drogas_df1=pd.read_excel('Datos/drogas/8.1_-_Prices_and_purities_of_drugs.xlsx')

# %%
# Selecciona las filas con valores nulos en la columna "Year"
null_unit = drogas_df1[drogas_df1['Unit'].isnull()]

# Imprime las filas seleccionadas
print(null_unit)
# Out:
#      Source    Region                              SubRegion
# 3496    ARQ      Asia  Near and Middle East/ South-West Asia  \
# 3528    ARQ  Americas                          South America
# 3532    ARQ      Asia                             South Asia
# 3533    ARQ      Asia                             South Asia
# 3534    ARQ      Asia                             South Asia
# 3574    ARQ    Europe                   South-Eastern Europe
# 3667    ARQ      Asia         Central Asia and Transcaucasia
# 3668    ARQ      Asia         Central Asia and Transcaucasia
# 3669    ARQ      Asia         Central Asia and Transcaucasia
# 3791    ARQ   Oceania              Australia and New Zealand
# 4199    ARQ  Americas                              Caribbean
# 4200    ARQ  Americas                              Caribbean
# 4209    ARQ    Europe             Western and Central Europe
# 4406    ARQ      Asia               East and South-East Asia
# ...

# %%
drogas_df1.head(50)
# Out:
#    Source  Region     SubRegion Country/Territory
# 0     ARQ  Africa   East Africa             Kenya  \
# 1     ARQ  Africa   East Africa             Kenya
# 2     ARQ  Africa   East Africa             Kenya
# 3     ARQ  Africa   East Africa             Kenya
# 4     ARQ  Africa   East Africa             Kenya
# 5     ARQ  Africa   East Africa             Kenya
# 6     ARQ  Africa   East Africa             Kenya
# 7     ARQ  Africa   East Africa             Kenya
# 8     ARQ  Africa   East Africa             Kenya
# 9     ARQ  Africa   East Africa             Kenya
# 10    ARQ  Africa   East Africa             Kenya
# 11    ARQ  Africa   East Africa             Kenya
# 12    ARQ  Africa   East Africa             Kenya
# 13    ARQ  Africa   East Africa             Kenya
# 14    ARQ  Africa   East Africa             Kenya
# 15    ARQ  Africa   East Africa        Madagascar
# 16    ARQ  Africa   East Africa        Madagascar
# 17    ARQ  Africa   East Africa        Madagascar
# ...
